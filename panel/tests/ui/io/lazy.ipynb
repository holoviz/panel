# %%
import pandas as pd
import panel as pn

pn.extension()

# %%
pn.widgets.Tabulator(pd.DataFrame({'x': [1, 2, 3]}), height=200).servable()

# %%
pn.pane.Perspective(pd.DataFrame({'x': [1, 2, 3]}), height=300).servable()
