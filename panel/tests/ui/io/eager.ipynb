# %%
import pandas as pd
import panel as pn

pn.extension('perspective', 'filedropper')

# %%
pn.pane.Perspective(pd.DataFrame({'x': [1, 2, 3]}), height=300).servable()

# %%
pn.widgets.FileDropper(height=200).servable()
